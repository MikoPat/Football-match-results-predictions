# %%
import pandas as pd
from sklearn.utils import shuffle

# %%
data = pd.read_csv('../Data/fianl_data_for_neural_network_all.csv', sep='\t')

# %%
data = data.drop('Unnamed: 0', axis=1)

# %%
list(data.columns)
# Out:
# ['home_team_last_5_search_team_summary_goals',
#  'home_team_last_5_search_team_summary_shots',
#  'home_team_last_5_search_team_summary_shots_on_target',
#  'home_team_last_5_search_team_summary_xg',
#  'home_team_last_5_search_team_summary_npxg',
#  'home_team_last_5_search_team_summary_xg_assist',
#  'home_team_last_5_search_team_summary_sca',
#  'home_team_last_5_search_team_summary_gca',
#  'home_team_last_5_search_team_passes_xg_assist',
#  'home_team_last_5_search_team_passes_passes_into_final_third',
#  'home_team_last_5_search_team_passes_passes_into_penalty_area',
#  'home_team_last_5_search_team_passes_crosses_into_penalty_area',
#  'home_team_last_5_search_team_possesion_touches_att_3rd',
#  'home_team_last_5_search_team_possesion_touches_att_pen_area',
#  'home_team_last_5_search_team_defensive_tackles_def_3rd',
#  'home_team_last_5_search_team_defensive_tackles_mid_3rd',
#  'home_team_last_5_search_team_defensive_blocked_shots',
#  'home_team_last_5_search_team_defensive_errors',
#  'home_team_last_5_search_team_miscellaneous_ball_recoveries',
#  'home_team_last_5_opponent_team_summary_goals',
#  'home_team_last_5_opponent_team_summary_shots',
#  'home_team_last_5_opponent_team_summary_shots_on_target',
#  'home_team_last_5_opponent_team_summary_xg',
#  'home_team_last_5_opponent_team_summary_npxg',
#  'home_team_last_5_opponent_team_summary_xg_assist',
#  'home_team_last_5_opponent_team_summary_sca',
#  'home_team_last_5_opponent_team_summary_gca',
#  'home_team_last_5_opponent_team_passes_xg_assist',
#  'home_team_last_5_opponent_team_passes_passes_into_final_third',
#  'home_team_last_5_opponent_team_passes_passes_into_penalty_area',
#  'home_team_last_5_opponent_team_passes_crosses_into_penalty_area',
#  'home_team_last_5_opponent_team_possesion_touches_att_3rd',
#  'home_team_last_5_opponent_team_possesion_touches_att_pen_area',
#  'home_team_last_5_opponent_team_defensive_tackles_def_3rd',
#  'home_team_last_5_opponent_team_defensive_tackles_mid_3rd',
#  'home_team_last_5_opponent_team_defensive_blocked_shots',
#  'home_team_last_5_opponent_team_defensive_errors',
#  'home_team_last_5_opponent_team_miscellaneous_ball_recoveries',
#  'home_team_last_5_search_team_elo',
#  'home_team_last_5_opponent_team_elo',
#  'home_team_last_5_rival_difference_elo',
#  'home_team_last_5_result',
#  'home_team_last_3_opponent_team_summary_goals',
#  'home_team_last_3_opponent_team_summary_shots',
#  'home_team_last_3_opponent_team_summary_shots_on_target',
#  'home_team_last_3_opponent_team_summary_xg',
#  'home_team_last_3_opponent_team_summary_npxg',
#  'home_team_last_3_opponent_team_summary_xg_assist',
#  'home_team_last_3_opponent_team_summary_sca',
#  'home_team_last_3_opponent_team_summary_gca',
#  'home_team_last_3_opponent_team_passes_xg_assist',
#  'home_team_last_3_opponent_team_passes_passes_into_final_third',
#  'home_team_last_3_opponent_team_passes_passes_into_penalty_area',
#  'home_team_last_3_opponent_team_passes_crosses_into_penalty_area',
#  'home_team_last_3_opponent_team_possesion_touches_att_3rd',
#  'home_team_last_3_opponent_team_possesion_touches_att_pen_area',
#  'home_team_last_3_opponent_team_defensive_tackles_def_3rd',
#  'home_team_last_3_opponent_team_defensive_tackles_mid_3rd',
#  'home_team_last_3_opponent_team_defensive_blocked_shots',
#  'home_team_last_3_opponent_team_defensive_errors',
#  'home_team_last_3_opponent_team_miscellaneous_ball_recoveries',
#  'home_team_last_3_search_team_summary_goals',
#  'home_team_last_3_search_team_summary_shots',
#  'home_team_last_3_search_team_summary_shots_on_target',
#  'home_team_last_3_search_team_summary_xg',
#  'home_team_last_3_search_team_summary_npxg',
#  'home_team_last_3_search_team_summary_xg_assist',
#  'home_team_last_3_search_team_summary_sca',
#  'home_team_last_3_search_team_summary_gca',
#  'home_team_last_3_search_team_passes_xg_assist',
#  'home_team_last_3_search_team_passes_passes_into_final_third',
#  'home_team_last_3_search_team_passes_passes_into_penalty_area',
#  'home_team_last_3_search_team_passes_crosses_into_penalty_area',
#  'home_team_last_3_search_team_possesion_touches_att_3rd',
#  'home_team_last_3_search_team_possesion_touches_att_pen_area',
#  'home_team_last_3_search_team_defensive_tackles_def_3rd',
#  'home_team_last_3_search_team_defensive_tackles_mid_3rd',
#  'home_team_last_3_search_team_defensive_blocked_shots',
#  'home_team_last_3_search_team_defensive_errors',
#  'home_team_last_3_search_team_miscellaneous_ball_recoveries',
#  'home_team_last_3_opponent_team_elo',
#  'home_team_last_3_search_team_elo',
#  'home_team_last_3_rival_difference_elo',
#  'home_team_last_3_result',
#  'away_team_last_5_opponent_team_summary_goals',
#  'away_team_last_5_opponent_team_summary_shots',
#  'away_team_last_5_opponent_team_summary_shots_on_target',
#  'away_team_last_5_opponent_team_summary_xg',
#  'away_team_last_5_opponent_team_summary_npxg',
#  'away_team_last_5_opponent_team_summary_xg_assist',
#  'away_team_last_5_opponent_team_summary_sca',
#  'away_team_last_5_opponent_team_summary_gca',
#  'away_team_last_5_opponent_team_passes_xg_assist',
#  'away_team_last_5_opponent_team_passes_passes_into_final_third',
#  'away_team_last_5_opponent_team_passes_passes_into_penalty_area',
#  'away_team_last_5_opponent_team_passes_crosses_into_penalty_area',
#  'away_team_last_5_opponent_team_possesion_touches_att_3rd',
#  'away_team_last_5_opponent_team_possesion_touches_att_pen_area',
#  'away_team_last_5_opponent_team_defensive_tackles_def_3rd',
#  'away_team_last_5_opponent_team_defensive_tackles_mid_3rd',
#  'away_team_last_5_opponent_team_defensive_blocked_shots',
#  'away_team_last_5_opponent_team_defensive_errors',
#  'away_team_last_5_opponent_team_miscellaneous_ball_recoveries',
#  'away_team_last_5_search_team_summary_goals',
#  'away_team_last_5_search_team_summary_shots',
#  'away_team_last_5_search_team_summary_shots_on_target',
#  'away_team_last_5_search_team_summary_xg',
#  'away_team_last_5_search_team_summary_npxg',
#  'away_team_last_5_search_team_summary_xg_assist',
#  'away_team_last_5_search_team_summary_sca',
#  'away_team_last_5_search_team_summary_gca',
#  'away_team_last_5_search_team_passes_xg_assist',
#  'away_team_last_5_search_team_passes_passes_into_final_third',
#  'away_team_last_5_search_team_passes_passes_into_penalty_area',
#  'away_team_last_5_search_team_passes_crosses_into_penalty_area',
#  'away_team_last_5_search_team_possesion_touches_att_3rd',
#  'away_team_last_5_search_team_possesion_touches_att_pen_area',
#  'away_team_last_5_search_team_defensive_tackles_def_3rd',
#  'away_team_last_5_search_team_defensive_tackles_mid_3rd',
#  'away_team_last_5_search_team_defensive_blocked_shots',
#  'away_team_last_5_search_team_defensive_errors',
#  'away_team_last_5_search_team_miscellaneous_ball_recoveries',
#  'away_team_last_5_opponent_team_elo',
#  'away_team_last_5_search_team_elo',
#  'away_team_last_5_rival_difference_elo',
#  'away_team_last_5_result',
#  'away_team_last_3_search_team_summary_goals',
#  'away_team_last_3_search_team_summary_shots',
#  'away_team_last_3_search_team_summary_shots_on_target',
#  'away_team_last_3_search_team_summary_xg',
#  'away_team_last_3_search_team_summary_npxg',
#  'away_team_last_3_search_team_summary_xg_assist',
#  'away_team_last_3_search_team_summary_sca',
#  'away_team_last_3_search_team_summary_gca',
#  'away_team_last_3_search_team_passes_xg_assist',
#  'away_team_last_3_search_team_passes_passes_into_final_third',
#  'away_team_last_3_search_team_passes_passes_into_penalty_area',
#  'away_team_last_3_search_team_passes_crosses_into_penalty_area',
#  'away_team_last_3_search_team_possesion_touches_att_3rd',
#  'away_team_last_3_search_team_possesion_touches_att_pen_area',
#  'away_team_last_3_search_team_defensive_tackles_def_3rd',
#  'away_team_last_3_search_team_defensive_tackles_mid_3rd',
#  'away_team_last_3_search_team_defensive_blocked_shots',
#  'away_team_last_3_search_team_defensive_errors',
#  'away_team_last_3_search_team_miscellaneous_ball_recoveries',
#  'away_team_last_3_opponent_team_summary_goals',
#  'away_team_last_3_opponent_team_summary_shots',
#  'away_team_last_3_opponent_team_summary_shots_on_target',
#  'away_team_last_3_opponent_team_summary_xg',
#  'away_team_last_3_opponent_team_summary_npxg',
#  'away_team_last_3_opponent_team_summary_xg_assist',
#  'away_team_last_3_opponent_team_summary_sca',
#  'away_team_last_3_opponent_team_summary_gca',
#  'away_team_last_3_opponent_team_passes_xg_assist',
#  'away_team_last_3_opponent_team_passes_passes_into_final_third',
#  'away_team_last_3_opponent_team_passes_passes_into_penalty_area',
#  'away_team_last_3_opponent_team_passes_crosses_into_penalty_area',
#  'away_team_last_3_opponent_team_possesion_touches_att_3rd',
#  'away_team_last_3_opponent_team_possesion_touches_att_pen_area',
#  'away_team_last_3_opponent_team_defensive_tackles_def_3rd',
#  'away_team_last_3_opponent_team_defensive_tackles_mid_3rd',
#  'away_team_last_3_opponent_team_defensive_blocked_shots',
#  'away_team_last_3_opponent_team_defensive_errors',
#  'away_team_last_3_opponent_team_miscellaneous_ball_recoveries',
#  'away_team_last_3_search_team_elo',
#  'away_team_last_3_opponent_team_elo',
#  'away_team_last_3_rival_difference_elo',
#  'away_team_last_3_result',
#  'result']
