# %%
import pandas as pd

# %%
italy = pd.read_csv('../Data/fianl_data_for_neural_network_italy.csv', sep='\t')
spain = pd.read_csv('../Data/fianl_data_for_neural_network_spain.csv', sep='\t')
france = pd.read_csv('../Data/fianl_data_for_neural_network_france.csv', sep='\t')
germany = pd.read_csv('../Data/fianl_data_for_neural_network_germany.csv', sep='\t')
england = pd.read_csv('../Data/fianl_data_for_neural_network_england.csv', sep='\t')

# %% [markdown]
# Początek kolejki - początek kolejki\
#
# **Italia**\
# 2022-2023 -> 2022-08-13	(1) - 2022-10-21 (11)\
# 2021-2022 -> 2021-08-21	(1) - 2021-10-30 (11)\
# 2020-2021 -> 2020-09-19 (1) - 2020-12-11 (11)\
# 2019-2020 -> 2019-08-24	(1) - 2019-11-02 (11)\
# 2018-2019 -> 2018-08-18 (1) - 2018-11-02 (11)\
# 2017-2018 -> 2017-08-19	(1) - 2017-10-28 (11)
#
# **Spain**\
# 2022-2023 -> 2022-08-12	(1) - 2022-10-22 (11)\
# 2021-2022 -> 2021-08-13	(1) - 2021-10-26 (11)\
# 2020-2021 -> 2020-09-12	(1) - 2020-11-27 (11)\
# 2019-2020 -> 2019-08-16 (1) - 2019-10-29 (11)\
# 2018-2019 -> 2018-08-17	(1) - 2018-11-03 (11)\
# 2017-2018 -> 2017-08-18 (1) - 2017-11-03 (11)
#
# **Germany**\
# 2022-2023 -> 2022-08-05	(1) - 2022-10-21 (11)\
# 2021-2022 -> 2021-08-13	(1) - 2021-11-05 (11)\
# 2020-2021 -> 2020-09-18	(1) - 2020-12-11 (11)\
# 2019-2020 -> 2019-08-16	(1) - 2019-11-08 (11)\
# 2018-2019 -> 2018-08-24 (1) - 2018-11-09 (11)\
# 2017-2018 -> 2017-08-18	(1) - 2017-11-03 (11)
#
# **France**\
# 2022-2023 -> 2022-08-05	(1) - 2022-10-14 (11)\
# 2021-2022 -> 2021-08-06	(1) - 2021-10-22 (11)\
# 2020-2021 -> 2020-08-21 (1) - 2020-11-20 (11)\
# 2019-2020 -> 2019-08-09	(1) - 2019-10-25 (11)\
# 2018-2019 -> 2018-08-10 (1) - 2018-10-26 (11)\
# 2017-2018 -> 2017-08-04	(1) - 2017-10-27 (11)
#
#
# **England**\
# 2022-2023 -> 2022-08-05	(1) - 2022-10-14 (11)\
# 2021-2022 -> 2021-08-13	(1) - 2021-11-05 (11)\
# 2020-2021 -> 2020-09-12 (1) - 2020-12-05 (11)\
# 2019-2020 -> 2019-08-09	(1) - 2019-11-02 (11)\
# 2018-2019 -> 2018-08-10 (1) - 2018-11-03 (11)\
# 2017-2018 -> 2017-08-11	(1) - 2017-11-04 (11)

# %%
# England
england = england.drop('Unnamed: 0', axis=1)

england['game_date'] = pd.to_datetime(germany['game_date'], errors='coerce')

england.drop(england[(germany['game_date'] >= '2022-08-05') & (england['game_date'] < '2022-10-14')].index, inplace = True)
england.drop(england[(germany['game_date'] >= '2021-08-13') & (england['game_date'] < '2021-11-05')].index, inplace = True)
england.drop(england[(germany['game_date'] >= '2020-09-12') & (england['game_date'] < '2020-12-05')].index, inplace = True)
england.drop(england[(germany['game_date'] >= '2019-08-09') & (england['game_date'] < '2019-11-02')].index, inplace = True)
england.drop(england[(germany['game_date'] >= '2018-08-10') & (england['game_date'] < '2018-11-03')].index, inplace = True)
england.drop(england[(germany['game_date'] >= '2017-08-11') & (england['game_date'] < '2017-11-04')].index, inplace = True)
# Out:
# /var/folders/_h/ljwht4gd7lb99rm1hm78h7_00000gn/T/ipykernel_16342/3094183970.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   england.drop(england[(germany['game_date'] >= '2022-08-05') & (england['game_date'] < '2022-10-14')].index, inplace = True)
# /var/folders/_h/ljwht4gd7lb99rm1hm78h7_00000gn/T/ipykernel_16342/3094183970.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   england.drop(england[(germany['game_date'] >= '2021-08-13') & (england['game_date'] < '2021-11-05')].index, inplace = True)
# /var/folders/_h/ljwht4gd7lb99rm1hm78h7_00000gn/T/ipykernel_16342/3094183970.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   england.drop(england[(germany['game_date'] >= '2020-09-12') & (england['game_date'] < '2020-12-05')].index, inplace = True)
# /var/folders/_h/ljwht4gd7lb99rm1hm78h7_00000gn/T/ipykernel_16342/3094183970.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   england.drop(england[(germany['game_date'] >= '2019-08-09') & (england['game_date'] < '2019-11-02')].index, inplace = True)
# /var/folders/_h/ljwht4gd7lb99rm1hm78h7_00000gn/T/ipykernel_16342/3094183970.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   england.drop(england[(germany['game_date'] >= '2018-08-10') & (england['game_date'] < '2018-11-03')].index, inplace = True)
# /var/folders/_h/ljwht4gd7lb99rm1hm78h7_00000gn/T/ipykernel_16342/3094183970.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   england.drop(england[(germany['game_date'] >= '2017-08-11') & (england['game_date'] < '2017-11-04')].index, inplace = True)

# %%
# Germany
germany = germany.drop('Unnamed: 0', axis=1)

germany['game_date'] = pd.to_datetime(germany['game_date'], errors='coerce')

germany.drop(germany[(germany['game_date'] >= '2022-08-05') & (germany['game_date'] < '2022-10-21')].index, inplace = True)
germany.drop(germany[(germany['game_date'] >= '2021-08-13') & (germany['game_date'] < '2021-11-05')].index, inplace = True)
germany.drop(germany[(germany['game_date'] >= '2020-09-18') & (germany['game_date'] < '2020-12-11')].index, inplace = True)
germany.drop(germany[(germany['game_date'] >= '2019-08-16') & (germany['game_date'] < '2019-11-08')].index, inplace = True)
germany.drop(germany[(germany['game_date'] >= '2018-08-24') & (germany['game_date'] < '2018-11-09')].index, inplace = True)
germany.drop(germany[(germany['game_date'] >= '2017-08-18') & (germany['game_date'] < '2017-11-03')].index, inplace = True)

# %%
# France
france = france.drop('Unnamed: 0', axis=1)

france['game_date'] = pd.to_datetime(france['game_date'], errors='coerce')

france.drop(france[(france['game_date'] >= '2022-08-05') & (france['game_date'] < '2022-10-14')].index, inplace = True)
france.drop(france[(france['game_date'] >= '2021-08-06') & (france['game_date'] < '2021-10-22')].index, inplace = True)
france.drop(france[(france['game_date'] >= '2020-08-21') & (france['game_date'] < '2020-11-20')].index, inplace = True)
france.drop(france[(france['game_date'] >= '2019-08-09') & (france['game_date'] < '2019-10-25')].index, inplace = True)
france.drop(france[(france['game_date'] >= '2018-08-10') & (france['game_date'] < '2018-10-26')].index, inplace = True)
france.drop(france[(france['game_date'] >= '2017-08-04') & (france['game_date'] < '2017-10-27')].index, inplace = True)

# %%
# Spain
spain = spain.drop('Unnamed: 0', axis=1)

spain['game_date'] = pd.to_datetime(spain['game_date'], errors='coerce')

spain.drop(spain[(spain['game_date'] >= '2022-08-12') & (spain['game_date'] < '2022-10-22')].index, inplace = True)
spain.drop(spain[(spain['game_date'] >= '2021-08-13') & (spain['game_date'] < '2021-10-26')].index, inplace = True)
spain.drop(spain[(spain['game_date'] >= '2020-09-12') & (spain['game_date'] < '2020-11-27')].index, inplace = True)
spain.drop(spain[(spain['game_date'] >= '2019-08-16') & (spain['game_date'] < '2019-10-29')].index, inplace = True)
spain.drop(spain[(spain['game_date'] >= '2018-08-17') & (spain['game_date'] < '2018-11-03')].index, inplace = True)
spain.drop(spain[(spain['game_date'] >= '2017-08-18') & (spain['game_date'] < '2017-11-03')].index, inplace = True)

# %%
# Italia
italy = italy.drop('Unnamed: 0', axis=1)

italy['game_date'] = pd.to_datetime(italy['game_date'], errors='coerce')

italy.drop(italy[(italy['game_date'] >= '2022-08-13') & (italy['game_date'] < '2022-10-22')].index, inplace = True)
italy.drop(italy[(italy['game_date'] >= '2021-08-21') & (italy['game_date'] < '2021-10-30')].index, inplace = True)
italy.drop(italy[(italy['game_date'] >= '2020-09-19') & (italy['game_date'] < '2020-12-11')].index, inplace = True)
italy.drop(italy[(italy['game_date'] >= '2019-08-24') & (italy['game_date'] < '2019-11-02')].index, inplace = True)
italy.drop(italy[(italy['game_date'] >= '2018-08-18') & (italy['game_date'] < '2018-11-02')].index, inplace = True)
italy.drop(italy[(italy['game_date'] >= '2017-08-19') & (italy['game_date'] < '2017-10-28')].index, inplace = True)

# %%
dane = pd.concat([england, germany, france, spain, italy], ignore_index=True, sort=False)

# %%
dane
# Out:
#       home_team_last_5_search_team_summary_goals  \
# 0                                            1.0
# 1                                            1.2
# 2                                            2.2
# 3                                            1.0
# 4                                            0.8
# ...                                          ...
# 8701                                         1.8
# 8702                                         1.0
# 8703                                         1.6
# 8704                                         1.2
# 8705                                         2.4
#
#       home_team_last_5_search_team_summary_shots  \
# 0                                           11.8
# 1                                           11.4
# 2                                           19.0
# 3                                           10.8
# 4                                           11.2
# ...                                          ...
# 8701                                        14.0
# 8702                                         9.4
# 8703                                        12.0
# 8704                                        13.6
# 8705                                        15.6
#
#       home_team_last_5_search_team_summary_shots_on_target  \
# 0                                                   3.6
# 1                                                   5.2
# 2                                                   7.0
# 3                                                   3.8
# 4                                                   2.0
# ...                                                 ...
# 8701                                                5.6
# 8702                                                3.4
# 8703                                                5.2
# 8704                                                5.6
# 8705                                                5.6
#
#       home_team_last_5_search_team_summary_xg  \
# 0                                        1.00
# 1                                        1.04
# 2                                        2.10
# 3                                        1.24
# 4                                        1.22
# ...                                       ...
# 8701                                     1.10
# 8702                                     0.88
# 8703                                     0.90
# 8704                                     1.04
# 8705                                     2.06
#
#       home_team_last_5_search_team_summary_npxg  \
# 0                                          1.00
# 1                                          0.86
# 2                                          2.10
# 3                                          1.24
# 4                                          1.06
# ...                                         ...
# 8701                                       1.10
# 8702                                       0.72
# 8703                                       0.90
# 8704                                       0.90
# 8705                                       1.76
#
#       home_team_last_5_search_team_summary_xg_assist  \
# 0                                               0.72
# 1                                               0.74
# 2                                               1.48
# 3                                               1.00
# 4                                               0.88
# ...                                              ...
# 8701                                            0.80
# 8702                                            0.52
# 8703                                            0.78
# 8704                                            0.60
# 8705                                            1.56
#
#       home_team_last_5_search_team_summary_sca  \
# 0                                         19.6
# 1                                         19.8
# 2                                         32.8
# 3                                         19.2
# 4                                         18.2
# ...                                        ...
# 8701                                      24.8
# 8702                                      16.8
# 8703                                      21.6
# 8704                                      21.6
# 8705                                      29.8
#
#       home_team_last_5_search_team_summary_gca  \
# 0                                          1.4
# 1                                          2.0
# 2                                          4.0
# 3                                          2.0
# 4                                          1.2
# ...                                        ...
# 8701                                       2.8
# 8702                                       1.8
# 8703                                       2.8
# 8704                                       2.2
# 8705                                       4.6
#
#       home_team_last_5_search_team_passes_xg_assist  \
# 0                                              0.72
# 1                                              0.74
# 2                                              1.48
# 3                                              1.00
# 4                                              0.88
# ...                                             ...
# 8701                                           0.80
# 8702                                           0.52
# 8703                                           0.78
# 8704                                           0.60
# 8705                                           1.56
#
#       home_team_last_5_search_team_passes_passes_into_final_third  ...  \
# 0                                                  26.8            ...
# 1                                                  21.6            ...
# 2                                                  47.0            ...
# 3                                                  25.0            ...
# 4                                                  24.4            ...
# ...                                                 ...            ...
# 8701                                               38.4            ...
# 8702                                               19.8            ...
# 8703                                               40.2            ...
# 8704                                               26.8            ...
# 8705                                               35.0            ...
#
#       away_team_last_3_search_team_elo  away_team_last_3_opponent_team_elo  \
# 0                          1642.826090                         1675.349772
# 1                          1703.039714                         1719.828451
# 2                          2041.754435                         1909.427165
# 3                          1822.588989                         1793.620565
# 4                          1727.575724                         1701.520386
# ...                                ...                                 ...
# 8701                       1528.692505                         1561.096354
# 8702                       1632.804728                         1589.065470
# 8703                       1673.859090                         1716.829224
# 8704                       1830.514445                         1865.725627
# 8705                       1748.221476                         1705.449056
#
#       away_team_last_3_rival_difference_elo  away_team_last_3_result  result  \
# 0                                -32.523682                 1.000000     3.0
# 1                                -16.788737                 1.000000     3.0
# 2                                132.327271                 1.666667     3.0
# 3                                 28.968424                 1.000000     0.0
# 4                                 26.055339                 2.333333     1.0
# ...                                     ...                      ...     ...
# 8701                             -32.403849                 2.000000     3.0
# 8702                              43.739258                 2.000000     3.0
# 8703                             -42.970133                 1.333333     3.0
# 8704                             -35.211182                 1.666667     1.0
# 8705                              42.772420                 0.666667     0.0
#
#       game_date       home_team  home_team_elo    away_team  away_team_elo
# 0    2022-10-14        West Ham    1768.621948       Fulham    1655.402832
# 1    2022-10-15  Crystal Palace    1748.520630        Leeds    1708.192261
# 2    2022-10-15         Arsenal    1889.969116    Liverpool    1984.582153
# 3    2022-10-15         Everton    1711.964233   Man United    1809.977295
# 4    2022-10-15          Forest    1587.895874  Aston Villa    1723.276001
# ...         ...             ...            ...          ...            ...
# 8701 2018-05-20          Napoli    1856.183838      Crotone    1546.066772
# 8702 2018-05-20            SPAL    1544.446411    Sampdoria    1614.712280
# 8703 2018-05-20           Milan    1709.776001   Fiorentina    1697.576904
# 8704 2018-05-20        Sassuolo    1601.294678         Roma    1844.738159
# 8705 2018-05-20           Lazio    1765.380859        Inter    1744.869751
#
# [8706 rows x 174 columns]

# %%
dane.to_csv('../Data/fianl_data_for_neural_network_2.csv', sep='\t', encoding='utf-8')
